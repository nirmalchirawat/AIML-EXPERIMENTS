# %% [markdown]
# write a python programto import and export data usingpandas and showthe details
# of the dataset like number of rows, columns, first five rows, size, number of
# missing values, sum, average, min and max values from the numerical column.

# %%
import pandas as pd

df = pd.read_csv("data.csv")

df.to_csv("exported_data.csv", index=False)

print("Number of Rows and Columns:", df.shape)

print("\nFirst Five Rows:")
print(df.head())

print("\nSize of Dataset:", df.size)

print("\nMissing Values in Each Column:")
print(df.isnull().sum())


print("\nStatistical Summary of Numerical Columns:")

print("\nSum:")
print(df.sum(numeric_only=True))

print("\nAverage:")
print(df.mean(numeric_only=True))

print("\nMinimum Values:")
print(df.min(numeric_only=True))

print("\nMaximum Values:")
print(df.max(numeric_only=True))
# Out:
# Number of Rows and Columns: (6, 4)
#
# First Five Rows:
#     Name  Age  Marks  Height
# 0   Aman   20   85.0     5.7
# 1   Riya   19   90.0     5.5
# 2  Karan   21   78.0     5.8
# 3   Neha   20    NaN     5.6
# 4  Rahul   22   88.0     NaN
#
# Size of Dataset: 24
#
# Missing Values in Each Column:
# Name      0
# Age       0
# Marks     1
# Height    1
# dtype: int64
#
# Statistical Summary of Numerical Columns:
#
# Sum:
# Age       121.0
# Marks     433.0
# Height     28.0
# dtype: float64
#
# Average:
# Age       20.166667
# Marks     86.600000
# Height     5.600000
# dtype: float64
#
# Minimum Values:
# Age       19.0
# Marks     78.0
# Height     5.4
# dtype: float64
#
# Maximum Values:
# Age       22.0
# Marks     92.0
# Height     5.8
# dtype: float64
